# %%
import pandas as pd
import seaborn as sp
import matplotlib.pyplot as plt

car_dataset=pd.read_csv('train-data.csv')

# %%
import warnings 

warnings.filterwarnings('ignore')

# %%
car_dataset
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
car_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
car_dataset.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
car_dataset.drop(["Unnamed: 0","New_Price"],axis=1,inplace=True)

# %%
car_dataset
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
car_dataset=car_dataset.dropna()
car_dataset
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
car_dataset=car_dataset.reset_index(drop=True)
car_dataset
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 5970                  Maruti Swift VDI       Delhi  2014              27365
# 5971          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 5972             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 5973                Maruti Wagon R VXI     Kolkata  2013              46000
# 5974             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
for i in range(car_dataset.shape[0]):
    car_dataset.at[i,'Company']=car_dataset['Name'][i].split()[0]
    car_dataset.at[i,'Mileage_kg/km']=car_dataset['Mileage'][i].split()[0]
    car_dataset.at[i,'Engine_cc']=car_dataset['Engine'][i].split()[0]
    car_dataset.at[i,'Power_bhp']=car_dataset['Power'][i].split()[0]

# %%
car_dataset
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 5970                  Maruti Swift VDI       Delhi  2014              27365
# 5971          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 5972             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 5973                Maruti Wagon R VXI     Kolkata  2013              46000
# 5974             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
car_dataset.drop("Name",axis=1,inplace=True)

# %%
car_dataset.drop("Mileage",axis=1,inplace=True)
car_dataset.drop("Engine",axis=1,inplace=True)
car_dataset.drop("Power",axis=1,inplace=True)

# %%
car_dataset
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 5970       Delhi  2014              27365    Diesel       Manual      First
# 5971      Jaipur  2015             100000    Diesel       Manual      First
# 5972      Jaipur  2012              55000    Diesel       Manual     Second
# 5973     Kolkata  2013              46000    Petrol       Manual      First
# 5974   Hyderabad  2011              47000    Diesel       Manual      First
#
# ...

# %%
car_dataset['Mileage_kg/km']=car_dataset['Mileage_kg/km'].astype(float)
car_dataset['Engine_cc']=car_dataset['Engine_cc'].astype(float)

# %%
car_dataset[car_dataset['Power_bhp']=='null']
# Out:
#        Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 76       Jaipur  2008             111111    Diesel       Manual      First
# 79    Hyderabad  2005              87591    Petrol       Manual      First
# 89    Hyderabad  2007              73745    Petrol       Manual      First
# 120      Mumbai  2005             102000    Petrol       Manual     Second
# 143       Kochi  2008              80759    Petrol       Manual      Third
# ...         ...   ...                ...       ...          ...        ...
# 5818    Chennai  2007              79000    Petrol       Manual      First
# 5830       Pune  2006              47200    Petrol       Manual     Second
# 5881       Pune  2010              85000    Petrol       Manual      First
# 5899    Chennai  2002              75000    Diesel       Manual      First
# 5941      Delhi  2013              70000    Diesel       Manual      First
#
#       Seats  Price   Company  Mileage_kg/km  Engine_cc Power_bhp
# ...

# %%
count=0
position=[]
for i in range(car_dataset.shape[0]):
    if car_dataset['Power_bhp'][i]=='null':
        count =count+1
        position.append(i)

# %%
car_dataset=car_dataset.drop(car_dataset.index[position])

car_dataset=car_dataset.reset_index(drop=True)

# %%
car_dataset
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 5867       Delhi  2014              27365    Diesel       Manual      First
# 5868      Jaipur  2015             100000    Diesel       Manual      First
# 5869      Jaipur  2012              55000    Diesel       Manual     Second
# 5870     Kolkata  2013              46000    Petrol       Manual      First
# 5871   Hyderabad  2011              47000    Diesel       Manual      First
#
# ...

# %%
car_dataset['Power_bhp']=car_dataset['Power_bhp'].astype(float)

# %%
car_dataset.Location.value_counts()
# Out:
# Location
# Mumbai        775
# Hyderabad     718
# Kochi         645
# Coimbatore    629
# Pune          594
# Delhi         545
# Kolkata       521
# Chennai       476
# Jaipur        402
# Bangalore     347
# Ahmedabad     220
# Name: count, dtype: int64

# %%
sp.catplot(y="Price",x="Location",data=car_dataset.sort_values('Price',ascending=False),kind="bar",height=6,aspect=3)

# %%
Location=car_dataset[['Location']]
Location=pd.get_dummies(Location)
Location
# Out:
#       Location_Ahmedabad  Location_Bangalore  Location_Chennai  \
# 0                  False               False             False
# 1                  False               False             False
# 2                  False               False              True
# 3                  False               False              True
# 4                  False               False             False
# ...                  ...                 ...               ...
# 5867               False               False             False
# 5868               False               False             False
# 5869               False               False             False
# 5870               False               False             False
# 5871               False               False             False
#
#       Location_Coimbatore  Location_Delhi  Location_Hyderabad  \
# 0                   False           False               False
# 1                   False           False               False
# ...

# %%
car_dataset.Fuel_Type.value_counts()
# Out:
# Fuel_Type
# Diesel    3152
# Petrol    2655
# CNG         55
# LPG         10
# Name: count, dtype: int64

# %%
Fuel_Types=car_dataset[['Fuel_Type']]
Fuel_Types=pd.get_dummies(Fuel_Types)
Fuel_Types
# Out:
#       Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_LPG  Fuel_Type_Petrol
# 0              True             False          False             False
# 1             False              True          False             False
# 2             False             False          False              True
# 3             False              True          False             False
# 4             False              True          False             False
# ...             ...               ...            ...               ...
# 5867          False              True          False             False
# 5868          False              True          False             False
# 5869          False              True          False             False
# 5870          False             False          False              True
# 5871          False              True          False             False
#
# [5872 rows x 4 columns]

# %%
Transmission=car_dataset[['Transmission']]
Transmission=pd.get_dummies(Transmission,drop_first=True)
Transmission
# Out:
#       Transmission_Manual
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                   False
# ...                   ...
# 5867                 True
# 5868                 True
# 5869                 True
# 5870                 True
# 5871                 True
#
# [5872 rows x 1 columns]

# %%
car_dataset.Owner_Type.value_counts()
# Out:
# Owner_Type
# First             4839
# Second             925
# Third              101
# Fourth & Above       7
# Name: count, dtype: int64

# %%
car_dataset['Owner_Type'].replace({"First":4,"Second":3,"Third":2,"Fourth & Above":1},inplace=True)
car_dataset
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission  Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual           4
# 1           Pune  2015              41000    Diesel       Manual           4
# 2        Chennai  2011              46000    Petrol       Manual           4
# 3        Chennai  2012              87000    Diesel       Manual           4
# 4     Coimbatore  2013              40670    Diesel    Automatic           3
# ...          ...   ...                ...       ...          ...         ...
# 5867       Delhi  2014              27365    Diesel       Manual           4
# 5868      Jaipur  2015             100000    Diesel       Manual           4
# 5869      Jaipur  2012              55000    Diesel       Manual           3
# 5870     Kolkata  2013              46000    Petrol       Manual           4
# 5871   Hyderabad  2011              47000    Diesel       Manual           4
#
# ...

# %%
car_dataset.drop('Company',axis=1,inplace=True)

# %%
final_train=pd.concat([car_dataset,Location,Fuel_Types,Transmission],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[194], line 1
# ----> 1 final_train=pd.concat([car_dataset,Location,Fuel_Types,Transmission],axis=1,inplace=True)
#       2 final_train
#
# TypeError: concat() got an unexpected keyword argument 'inplace'

# %%
final_train
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission  Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual           4
# 1           Pune  2015              41000    Diesel       Manual           4
# 2        Chennai  2011              46000    Petrol       Manual           4
# 3        Chennai  2012              87000    Diesel       Manual           4
# 4     Coimbatore  2013              40670    Diesel    Automatic           3
# ...          ...   ...                ...       ...          ...         ...
# 5867       Delhi  2014              27365    Diesel       Manual           4
# 5868      Jaipur  2015             100000    Diesel       Manual           4
# 5869      Jaipur  2012              55000    Diesel       Manual           3
# 5870     Kolkata  2013              46000    Petrol       Manual           4
# 5871   Hyderabad  2011              47000    Diesel       Manual           4
#
# ...

# %%
final_train.drop(['Location','Fuel_Type','Transmission'],axis=1,inplace=True)

# %%
final_train
# Out:
#       Year  Kilometers_Driven  Owner_Type  Seats  Price  Mileage_kg/km  \
# 0     2010              72000           4    5.0   1.75          26.60
# 1     2015              41000           4    5.0  12.50          19.67
# 2     2011              46000           4    5.0   4.50          18.20
# 3     2012              87000           4    7.0   6.00          20.77
# 4     2013              40670           3    5.0  17.74          15.20
# ...    ...                ...         ...    ...    ...            ...
# 5867  2014              27365           4    5.0   4.75          28.40
# 5868  2015             100000           4    5.0   4.00          24.40
# 5869  2012              55000           3    8.0   2.90          14.00
# 5870  2013              46000           4    5.0   2.65          18.90
# 5871  2011              47000           4    5.0   2.50          25.44
#
#       Engine_cc  Power_bhp  Location_Ahmedabad  Location_Bangalore  ...  \
# ...

# %%
price=final_train['Price']
final_train.drop(['Price'],axis=1,inplace=True)

# %%
final_train['Price']=price

# %%
final_train
# Out:
#       Year  Kilometers_Driven  Owner_Type  Seats  Mileage_kg/km  Engine_cc  \
# 0     2010              72000           4    5.0          26.60      998.0
# 1     2015              41000           4    5.0          19.67     1582.0
# 2     2011              46000           4    5.0          18.20     1199.0
# 3     2012              87000           4    7.0          20.77     1248.0
# 4     2013              40670           3    5.0          15.20     1968.0
# ...    ...                ...         ...    ...            ...        ...
# 5867  2014              27365           4    5.0          28.40     1248.0
# 5868  2015             100000           4    5.0          24.40     1120.0
# 5869  2012              55000           3    8.0          14.00     2498.0
# 5870  2013              46000           4    5.0          18.90      998.0
# 5871  2011              47000           4    5.0          25.44      936.0
#
# ...

# %%
sp.pairplot(car_dataset)

# %%
plt.figure(figsize=(18,18))

sp.heatmap(final_train.corr(),annot=True,cmap="RdYlGn")
plt.show()

# %%
X=final_train.drop('Price',axis=1)
X
# Out:
#       Year  Kilometers_Driven  Owner_Type  Seats  Mileage_kg/km  Engine_cc  \
# 0     2010              72000           4    5.0          26.60      998.0
# 1     2015              41000           4    5.0          19.67     1582.0
# 2     2011              46000           4    5.0          18.20     1199.0
# 3     2012              87000           4    7.0          20.77     1248.0
# 4     2013              40670           3    5.0          15.20     1968.0
# ...    ...                ...         ...    ...            ...        ...
# 5867  2014              27365           4    5.0          28.40     1248.0
# 5868  2015             100000           4    5.0          24.40     1120.0
# 5869  2012              55000           3    8.0          14.00     2498.0
# 5870  2013              46000           4    5.0          18.90      998.0
# 5871  2011              47000           4    5.0          25.44      936.0
#
# ...

# %%
y=final_train['Price']
y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 5867     4.75
# 5868     4.00
# 5869     2.90
# 5870     2.65
# 5871     2.50
# Name: Price, Length: 5872, dtype: float64

# %%
from sklearn.tree import ExtraTreeRegressor

selection=ExtraTreeRegressor()
selection.fit(X,y)
# Out:
# ExtraTreeRegressor()

# %%
plt.figure(figsize=(12,18))

feat_importances=pd.Series(selection.feature_importances_,index=X.columns)
feat_importances.nlargest(20).plot(kind="barh")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

linerar_reg=LinearRegression()
linear=linerar_reg.fit(X_train,y_train)
y_predic=linerar_reg.predict(x_test)
print(linerar_reg.score(X_train,y_train))
# Out:
# 0.7005621804529995

# %%
print(linerar_reg.score(x_test,y_test))
# Out:
# 0.7256102038308834

# %%
plt.scatter(y_test,y_predic)

# %%
from sklearn import linear_model
lasso_reg=linear_model.Lasso(alpha=50,tol=0.1)
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=50, tol=0.1)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.6015357172320285

# %%
from sklearn.tree import DecisionTreeRegressor

df_reg=DecisionTreeRegressor()
decision=df_reg.fit(X_train,y_train)
y_predic=df_reg.predict(x_test)
print(df_reg.score(X_train,y_train))
print(df_reg.score(x_test,y_test))
# Out:
# 0.9999957727341057
# 0.8465335107163934

# %%
from sklearn.model_selection import cross_val_score
result=cross_val_score(DecisionTreeRegressor(splitter='best',min_samples_leaf=2,max_depth=15),X,y,cv=5)
result
# Out:
# array([0.81327694, 0.8506716 , 0.82833987, 0.75866495, 0.7813031 ])

# %%
from sklearn.ensemble import RandomForestRegressor

rdf_reg=RandomForestRegressor()
randoms=rdf_reg.fit(X_train,y_train)
y_predic=rdf_reg.predict(x_test)
print(df_reg.score(X_train,y_train))
print(df_reg.score(x_test,y_test))
# Out:
# 0.9999957727341057
# 0.8465335107163934

# %%
from sklearn.model_selection import cross_val_score
result=cross_val_score(RandomForestRegressor(),X,y,cv=5)
result
# Out:
# array([0.9110495 , 0.84116817, 0.88275448, 0.84709051, 0.86237799])

# %%
result.mean()
# Out:
# np.float64(0.8688881284784407)
